# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Create a reference the CSV file desired
csv_path = Path("Resources/JC-202305-citibike-tripdata.csv")

# Read the CSV into a Pandas DataFrame
May2023_df = pd.read_csv(csv_path, low_memory=False)

# Print data to the screen
May2023_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      BC145343639B5E5B   classic_bike  2023-05-31 12:27:28
# 1      A0CE41F47514FF5C   classic_bike  2023-05-01 18:12:37
# 2      D588077E3D7E2AFD  electric_bike  2023-05-28 17:37:58
# 3      89AC48A5584B2DB4   classic_bike  2023-05-27 21:01:37
# 4      709E0B11AB4A0E6C   classic_bike  2023-05-22 12:38:54
# ...                 ...            ...                  ...
# 95997  9549398286BB59B5    docked_bike  2023-05-27 13:24:51
# 95998  AB0790683044D89E   classic_bike  2023-05-18 17:12:07
# 95999  68226FA538A405CA   classic_bike  2023-05-05 18:44:57
# 96000  CABAC21C0F0140A5   classic_bike  2023-05-16 11:56:11
# 96001  4AABD797EF6F7BB2   classic_bike  2023-05-30 11:04:46
#
#                   ended_at                            start_station_name  \
# 0      2023-05-31 12:38:36                                Pershing Field
# 1      2023-05-01 18:29:03                                Pershing Field
# ...

# %%
# Check Count

May2023_df.count()
# Out:
# ride_id               96002
# rideable_type         96002
# started_at            96002
# ended_at              96002
# start_station_name    96002
# start_station_id      96002
# end_station_name      95736
# end_station_id        95736
# start_lat             96002
# start_lng             96002
# end_lat               95865
# end_lng               95865
# member_casual         96002
# dtype: int64

# %%
# clean May2023_df & Check Count

May2023_cleaned_df = May2023_df.dropna(how="any")
May2023_cleaned_df.count()
# Out:
# ride_id               95736
# rideable_type         95736
# started_at            95736
# ended_at              95736
# start_station_name    95736
# start_station_id      95736
# end_station_name      95736
# end_station_id        95736
# start_lat             95736
# start_lng             95736
# end_lat               95736
# end_lng               95736
# member_casual         95736
# dtype: int64

# %%
# Export file as .csv

May2023_cleaned_df.to_csv("Resources/May2023_citibike_cleaned.csv", index=False, header=True)

# %%
# Create a reference the CSV file desired
csv_path = Path("Resources/JC-202306-citibike-tripdata.csv")

# Read the CSV into a Pandas DataFrame
June2023_df = pd.read_csv(csv_path, low_memory=False)

# Print the first five rows of data to the screen
June2023_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1      9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2      C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3      2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4      E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                 ...            ...                  ...
# 97018  2C69F8EF2A1BDD90   classic_bike  2023-06-30 19:41:00
# 97019  43E592256BC287BB   classic_bike  2023-06-20 18:55:02
# 97020  4C3A7521689C560C  electric_bike  2023-06-22 19:24:22
# 97021  9AAA8F2E630456E7   classic_bike  2023-06-30 13:34:09
# 97022  064CE90800E9C21F   classic_bike  2023-06-13 17:23:31
#
#                   ended_at             start_station_name start_station_id  \
# 0      2023-06-27 16:10:27                        Hilltop            JC019
# 1      2023-06-24 10:55:27          Baldwin at Montgomery            JC020
# ...

# %%
# Check Count

June2023_df.count()
# Out:
# ride_id               97023
# rideable_type         97023
# started_at            97023
# ended_at              97023
# start_station_name    96968
# start_station_id      96968
# end_station_name      96662
# end_station_id        96662
# start_lat             97023
# start_lng             97023
# end_lat               96935
# end_lng               96935
# member_casual         97023
# dtype: int64

# %%
# clean June2023_df & Check Count

June2023_cleaned_df = June2023_df.dropna(how="any")
June2023_cleaned_df.count()
# Out:
# ride_id               96662
# rideable_type         96662
# started_at            96662
# ended_at              96662
# start_station_name    96662
# start_station_id      96662
# end_station_name      96662
# end_station_id        96662
# start_lat             96662
# start_lng             96662
# end_lat               96662
# end_lng               96662
# member_casual         96662
# dtype: int64

# %%
# Export file as .csv

June2023_cleaned_df.to_csv("Resources/June2023_citibike_cleaned.csv.", index=False, header=True)

# %%
# Create a reference the CSV file desired
csv_path = Path("Resources/JC-202307-citibike-tripdata.csv")

# Read the CSV into a Pandas DataFrame
July2023_df = pd.read_csv(csv_path, low_memory=False)

# Print the first five rows of data to the screen
July2023_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       7A68381621C25F78   classic_bike  2023-07-17 17:16:34
# 1       0F814CA67B2FA120   classic_bike  2023-07-26 19:40:15
# 2       775A38967EBF5FB4  electric_bike  2023-07-01 12:12:22
# 3       D93B742DCE1C1447   classic_bike  2023-07-20 19:10:18
# 4       AA7A6863B4B92169  electric_bike  2023-07-07 19:33:59
# ...                  ...            ...                  ...
# 106603  944F5CD711E7688E   classic_bike  2023-07-25 18:21:52
# 106604  4665B542F79F8C43  electric_bike  2023-07-26 22:22:20
# 106605  789D45FDEBC19E83   classic_bike  2023-07-31 07:57:29
# 106606  FFBE463288D36C2A   classic_bike  2023-07-07 17:52:09
# 106607  4DACECF4EBBEB60C   classic_bike  2023-07-26 20:54:16
#
#                    ended_at     start_station_name start_station_id  \
# 0       2023-07-17 17:20:52            Astor Place            JC077
# 1       2023-07-26 19:44:37        Adams St & 2 St            HB407
# ...

# %%
# Check Count

July2023_df.count()
# Out:
# ride_id               106608
# rideable_type         106608
# started_at            106608
# ended_at              106608
# start_station_name    106601
# start_station_id      106601
# end_station_name      106216
# end_station_id        106216
# start_lat             106608
# start_lng             106608
# end_lat               106486
# end_lng               106486
# member_casual         106608
# dtype: int64

# %%
# clean July2023_df & Check Count

July2023_cleaned_df = July2023_df.dropna(how="any")
July2023_cleaned_df.count()
# Out:
# ride_id               106216
# rideable_type         106216
# started_at            106216
# ended_at              106216
# start_station_name    106216
# start_station_id      106216
# end_station_name      106216
# end_station_id        106216
# start_lat             106216
# start_lng             106216
# end_lat               106216
# end_lng               106216
# member_casual         106216
# dtype: int64

# %%
# Export file as .csv

July2023_cleaned_df.to_csv("Resources/July2023_citibike_cleaned.csv", index=False, header=True)

# %%
frames  = [May2023_cleaned_df, June2023_cleaned_df, July2023_cleaned_df]
May_June_July_cleaned_combined_df =  pd.concat(frames)
May_June_July_cleaned_combined_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       BC145343639B5E5B   classic_bike  2023-05-31 12:27:28
# 1       A0CE41F47514FF5C   classic_bike  2023-05-01 18:12:37
# 2       D588077E3D7E2AFD  electric_bike  2023-05-28 17:37:58
# 3       89AC48A5584B2DB4   classic_bike  2023-05-27 21:01:37
# 4       709E0B11AB4A0E6C   classic_bike  2023-05-22 12:38:54
# ...                  ...            ...                  ...
# 106603  944F5CD711E7688E   classic_bike  2023-07-25 18:21:52
# 106604  4665B542F79F8C43  electric_bike  2023-07-26 22:22:20
# 106605  789D45FDEBC19E83   classic_bike  2023-07-31 07:57:29
# 106606  FFBE463288D36C2A   classic_bike  2023-07-07 17:52:09
# 106607  4DACECF4EBBEB60C   classic_bike  2023-07-26 20:54:16
#
#                    ended_at start_station_name start_station_id  \
# 0       2023-05-31 12:38:36     Pershing Field            JC024
# 1       2023-05-01 18:29:03     Pershing Field            JC024
# ...

# %%
May_June_July_cleaned_combined_df.count()
# Out:
# ride_id               298614
# rideable_type         298614
# started_at            298614
# ended_at              298614
# start_station_name    298614
# start_station_id      298614
# end_station_name      298614
# end_station_id        298614
# start_lat             298614
# start_lng             298614
# end_lat               298614
# end_lng               298614
# member_casual         298614
# dtype: int64

# %%
# Export file as .csv

May_June_July_cleaned_combined_df.to_csv("Resources/May_June_July_cleaned_combined_df.csv", index=False, header=True)

# %%
May_June_July_cleaned_combined_df['start_station_id'].value_counts().head(10)
# Out:
# start_station_id
# JC115    14705
# HB102    12383
# HB103    10823
# HB101     7904
# JC066     7615
# HB201     7361
# HB105     7313
# JC009     6685
# JC008     6626
# HB502     5779
# Name: count, dtype: int64

# %%
combined_top_ten_starting_df = May_June_July_cleaned_combined_df.loc[May_June_July_cleaned_combined_df['start_station_id'].isin(['JC115', 'HB102', 'HB103', 'HB101', 'JC066', 'HB201', 'HB105', 'JC009', 'JC008', 'HB502'])]
combined_top_ten_starting_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 25      31AE38E870A8C49F   classic_bike  2023-05-02 18:08:04
# 35      1659DA6BB6C03BA1   classic_bike  2023-05-15 16:23:41
# 37      B38FEDF86081BB09  electric_bike  2023-05-27 15:25:42
# 38      4FC3A1F7224963AD  electric_bike  2023-05-10 17:41:45
# 50      D39363573C3B9029   classic_bike  2023-05-26 16:42:38
# ...                  ...            ...                  ...
# 106513  E8D2F796B85EF5DE   classic_bike  2023-07-05 00:45:02
# 106514  5EA084016787E93E   classic_bike  2023-07-17 14:04:34
# 106515  E7D33ABDA59C72E7  electric_bike  2023-07-07 02:28:37
# 106516  0DD0F2681C4BC9A0   classic_bike  2023-07-08 22:48:42
# 106517  04141AD68D0F481D   classic_bike  2023-07-26 15:22:55
#
#                    ended_at                       start_station_name  \
# 25      2023-05-02 18:13:47  Hoboken Terminal - River St & Hudson Pl
# 35      2023-05-15 16:26:33  Hoboken Terminal - River St & Hudson Pl
# ...

# %%
combined_top_ten_starting_df.count()
# Out:
# ride_id               87194
# rideable_type         87194
# started_at            87194
# ended_at              87194
# start_station_name    87194
# start_station_id      87194
# end_station_name      87194
# end_station_id        87194
# start_lat             87194
# start_lng             87194
# end_lat               87194
# end_lng               87194
# member_casual         87194
# dtype: int64

# %%
# Export file as .csv

combined_top_ten_starting_df.to_csv("Resources/combined_top_ten_starting_df.csv", index=False, header=True)

# %%
May_June_July_cleaned_combined_df['start_station_id'].value_counts().tail(10)
# Out:
# start_station_id
# 5989.02    1
# 6072.06    1
# 6644.08    1
# 6717.06    1
# 5712.03    1
# 5746.14    1
# 5593.02    1
# 5411.08    1
# 6535.04    1
# 5351.07    1
# Name: count, dtype: int64

# %%
bottom_ten_stations = {
    'start_station_id': ['JC115', 'HB102', 'HB103', 'HB101', 'JC066', 'HB201', 'HB105', 'JC009', 'JC008', 'HB502']
} 

combined_bottom_ten_starting_df = May_June_July_cleaned_combined_df.loc[May_June_July_cleaned_combined_df['start_station_id'].isin(['J5989.02', '6072.06', '6644.08', '6717.06', '5712.03', '5746.14', '5593.02', '5411.08', '6535.04', '5351.07'])]
combined_bottom_ten_starting_df
# Out:
#                  ride_id rideable_type           started_at  \
# 33010   8743BE53DDD915D1  classic_bike  2023-05-26 11:58:17
# 33096   16A08B322E1BF0F7  classic_bike  2023-05-26 10:14:38
# 33336   0432950E336838D2  classic_bike  2023-05-23 20:15:52
# 33902   828A3908A4A3D3CB  classic_bike  2023-05-23 12:41:55
# 33944   256851F4DE1FC002  classic_bike  2023-05-23 13:50:24
# 35025   490234F8EC50FE02  classic_bike  2023-05-25 19:17:50
# 35580   AFF80E596BEC7138  classic_bike  2023-05-25 19:55:23
# 37515   A838ED866ED431FD  classic_bike  2023-05-23 13:40:56
# 101490  667518E9B3709E09  classic_bike  2023-07-19 12:13:17
#
#                    ended_at        start_station_name start_station_id  \
# 33010   2023-05-26 12:14:34   W 34 St & Hudson Blvd E          6535.04
# 33096   2023-05-26 10:26:12       Driggs Ave & N 9 St          5411.08
# 33336   2023-05-23 20:47:02            E 2 St & 2 Ave          5593.02
# 33902   2023-05-23 12:48:40           E 11 St & 1 Ave          5746.14
# ...

# %%
# Export file as .csv

combined_bottom_ten_starting_df.to_csv("Resources/combined_bottom_ten_starting_df.csv", index=False, header=True)
